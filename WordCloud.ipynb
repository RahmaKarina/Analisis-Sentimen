# %%
import pandas as pd 
import numpy as np

# %%
df_new = pd.read_csv("Hasil Label-Preproc - Versi uji 2.csv")
df_new.shape
# Out:
# (26840, 5)

# %%
df_new
# Out:
#                          tanggal  \
# 0      2022-12-06 13:26:39+00:00
# 1      2022-12-06 13:22:10+00:00
# 2      2022-12-06 13:09:54+00:00
# 3      2022-12-06 13:09:44+00:00
# 4      2022-12-06 12:58:54+00:00
# ...                          ...
# 26835  2023-03-05 04:25:21+00:00
# 26836  2023-03-05 04:25:05+00:00
# 26837  2023-03-05 04:22:27+00:00
# 26838  2023-02-23 13:38:12+00:00
# 26839  2023-01-05 02:50:50+00:00
#
#                                                     teks  \
# 0      b'RT @harismha: Tolong min @infomalang, info y...
# 1      b'Pergi ke kampus itu challenging bangeytttt, ...
# 2          b'tau gt kemaren ganti akun gojek aja anjir.'
# 3      b'@dukakunaon Minta jemput  abang gojek lebih ...
# 4      b'Doa ku tiap mau order gojek balik \xe2\x80\x...
# ...                                                  ...
# 26835  b'@gojekindonesia ini paylater gojek lg eror a...
# 26836  b'@dykzvn @gojekindonesia Say godbye gojek apk...
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Polarity == 0 positive
train_s1 = df_new[df_new["Sentiment"] == 'Positive']
all_text_s1 = ' '.join(word for word in train_s1["Stemming"])
wordcloud = WordCloud(width=1000, height=1000, colormap='Blues', background_color='black', mode='RGBA').generate(all_text_s1)
plt.figure( figsize=(10,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# Polarity == 1 negatif
train_s2 = df_new[df_new["Sentiment"] == 'Negative']
all_text_s2 = ' '.join(word for word in train_s2["Stemming"])
wordcloud = WordCloud(width=1000, height=1000, colormap='Reds', background_color='black', mode='RGBA').generate(all_text_s2)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
df_new['Sentiment'].value_counts()
# Out:
# Positive    17220
# Negative     9620
# Name: Sentiment, dtype: int64
